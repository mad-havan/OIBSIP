# %% [markdown]
# <a href="https://colab.research.google.com/github/mad-havan/OIBSIP/blob/main/SALES_PREDICTION_USING_PYTHON.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Lasso
from sklearn import metrics
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

# %%
sales_df=pd.read_csv("/content/Advertising.csv")

# %% [markdown]
# **DATA PREPROCESSING**

# %%
sales_df.head()
# Out:
#    Unnamed: 0     TV  Radio  Newspaper  Sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
sales_df.isnull().sum()
# Out:
# Unnamed: 0    0
# TV            0
# Radio         0
# Newspaper     0
# Sales         0
# dtype: int64

# %%
sales_df.value_counts()
# Out:
# Unnamed: 0  TV     Radio  Newspaper  Sales
# 1           230.1  37.8   69.2       22.1     1
# 138         273.7  28.9   59.7       20.8     1
# 128         80.2   0.0    9.2        8.8      1
# 129         220.3  49.0   3.2        24.7     1
# 130         59.6   12.0   43.1       9.7      1
#                                              ..
# 70          216.8  43.9   27.2       22.3     1
# 71          199.1  30.6   38.7       18.3     1
# 72          109.8  14.3   31.7       12.4     1
# 73          26.8   33.0   19.3       8.8      1
# 200         232.1  8.6    8.7        13.4     1
# Length: 200, dtype: int64

# %%
sales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  200 non-null    int64
#  1   TV          200 non-null    float64
#  2   Radio       200 non-null    float64
#  3   Newspaper   200 non-null    float64
#  4   Sales       200 non-null    float64
# dtypes: float64(4), int64(1)
# memory usage: 7.9 KB

# %%
sales_df.shape
# Out:
# (200, 5)

# %%
sales_df.describe()
# Out:
#        Unnamed: 0          TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000  200.000000
# mean   100.500000  147.042500   23.264000   30.554000   14.022500
# std     57.879185   85.854236   14.846809   21.778621    5.217457
# min      1.000000    0.700000    0.000000    0.300000    1.600000
# 25%     50.750000   74.375000    9.975000   12.750000   10.375000
# 50%    100.500000  149.750000   22.900000   25.750000   12.900000
# 75%    150.250000  218.825000   36.525000   45.100000   17.400000
# max    200.000000  296.400000   49.600000  114.000000   27.000000

# %%
sales_df=sales_df.drop(['Unnamed: 0'],axis=1)
sales_df
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3    9.3
# 3    151.5   41.3       58.5   18.5
# 4    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]

# %%
sales_df.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %% [markdown]
# **DATA VISUALIZATION**

# %%
cn=sales_df.corr()
plt.figure(figsize=(10,10))
sns.heatmap(cn,annot=True)
# Out:
# <Axes: >

# %%
sns.pairplot(sales_df, hue='Sales')

# %%
sns.histplot(sales_df['Sales'],bins=15)
# Out:
# <Axes: xlabel='Sales', ylabel='Count'>

# %%
sns.histplot(sales_df['TV'],bins=15)
# Out:
# <Axes: xlabel='TV', ylabel='Count'>

# %%
sns.histplot(sales_df['Radio'],bins=15)
# Out:
# <Axes: xlabel='Radio', ylabel='Count'>

# %%
sns.histplot(sales_df['Newspaper'],bins=15)
# Out:
# <Axes: xlabel='Newspaper', ylabel='Count'>

# %%
X=sales_df.drop(['Sales'],axis=1)
X.head()
# Out:
#       TV  Radio  Newspaper
# 0  230.1   37.8       69.2
# 1   44.5   39.3       45.1
# 2   17.2   45.9       69.3
# 3  151.5   41.3       58.5
# 4  180.8   10.8       58.4

# %%
Y=sales_df['Sales']
Y.head()
# Out:
# 0    22.1
# 1    10.4
# 2     9.3
# 3    18.5
# 4    12.9
# Name: Sales, dtype: float64

# %% [markdown]
# **TRAIN TEST SPLIT**

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2,random_state=42)

# %% [markdown]
# **Using Linear Regression**
# Train the model

# %%
model=LinearRegression()

# %%
model.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %% [markdown]
# **Model Evaluation**

# %%
y_pred=model.predict(X_test)

# %%
accuracy=metrics.r2_score(Y_test,y_pred)*100
accuracy
# Out:
# 89.9438024100912

# %%
plt.scatter(Y_test,y_pred)
sns.regplot(x=Y_test,y=y_pred,ci=None,color='blue')
plt.xlabel('Actual sales')
plt.ylabel('Predicted sales')
plt.title('Actual sales vs Predicted sales')
plt.show()

# %%
pred_df=pd.DataFrame({'Actual Sales':Y_test,'Predicted Sales':y_pred,'Difference':Y_test-y_pred})
pred_df
# Out:
#      Actual Sales  Predicted Sales  Difference
# 95           16.9        16.408024    0.491976
# 15           22.4        20.889882    1.510118
# 30           21.4        21.553843   -0.153843
# 158           7.3        10.608503   -3.308503
# 128          24.7        22.112373    2.587627
# 115          12.6        13.105592   -0.505592
# 69           22.3        21.057192    1.242808
# 170           8.4         7.461010    0.938990
# 174          11.5        13.606346   -2.106346
# 45           14.9        15.155070   -0.255070
# 66            9.5         9.048320    0.451680
# 182           8.7         6.653283    2.046717
# 165          11.9        14.345545   -2.445545
# 78            5.3         8.903493   -3.603493
# 186          10.3         9.689590    0.610410
# 177          11.7        12.164944   -0.464944
# 56            5.5         8.736284   -3.236284
# 152          16.6        16.265073    0.334927
# 82           11.3        10.277596    1.022404
# 68           18.9        18.831091    0.068909
# 124          19.7        19.560367    0.139633
# 16           12.5        13.251035   -0.751035
# 148          10.9        12.336207   -1.436207
# 93           22.2        21.306951    0.893049
# 65            9.3         7.827403    1.472597
# 60            8.1         5.809574    2.290426
# 84           21.7        20.757532    0.942468
# 67           13.4        11.981381    1.418619
# 125          10.6         9.183496    1.416504
# 132           5.7         8.506699   -2.806699
# 9            10.6        12.466468   -1.866468
# 18           11.3        10.003377    1.296623
# 55           23.7        21.387671    2.312329
# 75            8.7        12.249664   -3.549664
# 150          16.1        18.266615   -2.166615
# 104          20.7        20.137663    0.562337
# 135          11.6        14.055140   -2.455140
# 137          20.8        20.854112   -0.054112
# 164          11.9        11.017444    0.882556
# 76            6.9         4.568996    2.331004

# %% [markdown]
# **Using Decision Tree Regressor**

# %%
model=DecisionTreeRegressor()

# %%
model.fit(X_train,Y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_pred=model.predict(X_test)

# %%
accuracy=metrics.r2_score(Y_test,y_pred)*100
accuracy
# Out:
# 94.78433915656387

# %%
plt.scatter(Y_test,y_pred)
sns.regplot(x=Y_test,y=y_pred,ci=None,color='blue')
plt.xlabel('Actual sales')
plt.ylabel('Predicted sales')
plt.title('Actual sales vs Predicted sales')
plt.show()

# %%
pred_df=pd.DataFrame({'Actual Sales':Y_test,'Predicted Sales':y_pred,'Difference':Y_test-y_pred})
pred_df
# Out:
#      Actual Sales  Predicted Sales  Difference
# 95           16.9             19.2        -2.3
# 15           22.4             21.2         1.2
# 30           21.4             20.2         1.2
# 158           7.3              7.2         0.1
# 128          24.7             23.8         0.9
# 115          12.6             13.3        -0.7
# 69           22.3             22.6        -0.3
# 170           8.4              9.7        -1.3
# 174          11.5             11.7        -0.2
# 45           14.9             14.1         0.8
# 66            9.5              4.8         4.7
# 182           8.7              8.6         0.1
# 165          11.9             12.5        -0.6
# 78            5.3              6.6        -1.3
# 186          10.3             10.3         0.0
# 177          11.7             12.6        -0.9
# 56            5.5              6.6        -1.1
# 152          16.6             17.0        -0.4
# 82           11.3             11.8        -0.5
# 68           18.9             20.2        -1.3
# 124          19.7             20.1        -0.4
# 16           12.5             10.9         1.6
# 148          10.9             10.8         0.1
# 93           22.2             24.4        -2.2
# 65            9.3              9.7        -0.4
# 60            8.1              8.7        -0.6
# 84           21.7             22.6        -0.9
# 67           13.4             12.2         1.2
# 125          10.6              9.7         0.9
# 132           5.7              4.8         0.9
# 9            10.6             11.6        -1.0
# 18           11.3             10.9         0.4
# 55           23.7             21.2         2.5
# 75            8.7              9.3        -0.6
# 150          16.1             15.7         0.4
# 104          20.7             19.6         1.1
# 135          11.6             13.6        -2.0
# 137          20.8             20.2         0.6
# 164          11.9             12.2        -0.3
# 76            6.9              7.2        -0.3

# %% [markdown]
# **Using Random Forest Regressor**

# %%
model=RandomForestRegressor()

# %%
model.fit(X_train,Y_train)
# Out:
# RandomForestRegressor()

# %%
y_pred=model.predict(X_test)

# %%
accuracy=metrics.r2_score(Y_test,y_pred)*100
accuracy
# Out:
# 98.3045098437183

# %%
plt.scatter(Y_test,y_pred)
sns.regplot(x=Y_test,y=y_pred,ci=None,color='blue')
plt.xlabel('Actual sales')
plt.ylabel('Predicted sales')
plt.title('Actual sales vs Predicted sales')
plt.show()

# %%
pred_df=pd.DataFrame({'Actual Sales':Y_test,'Predicted Sales':y_pred,'Difference':Y_test-y_pred})
pred_df
# Out:
#      Actual Sales  Predicted Sales  Difference
# 95           16.9           17.486      -0.586
# 15           22.4           21.654       0.746
# 30           21.4           20.877       0.523
# 158           7.3            7.010       0.290
# 128          24.7           23.168       1.532
# 115          12.6           13.268      -0.668
# 69           22.3           22.559      -0.259
# 170           8.4            9.684      -1.284
# 174          11.5           11.816      -0.316
# 45           14.9           15.650      -0.750
# 66            9.5            7.514       1.986
# 182           8.7            9.110      -0.410
# 165          11.9           12.119      -0.219
# 78            5.3            5.051       0.249
# 186          10.3           10.494      -0.194
# 177          11.7           12.642      -0.942
# 56            5.5            6.577      -1.077
# 152          16.6           16.463       0.137
# 82           11.3           11.417      -0.117
# 68           18.9           19.786      -0.886
# 124          19.7           20.082      -0.382
# 16           12.5           12.907      -0.407
# 148          10.9           10.402       0.498
# 93           22.2           21.756       0.444
# 65            9.3           10.108      -0.808
# 60            8.1            8.933      -0.833
# 84           21.7           22.030      -0.330
# 67           13.4           12.625       0.775
# 125          10.6           10.199       0.401
# 132           5.7            5.442       0.258
# 9            10.6           11.608      -1.008
# 18           11.3           10.949       0.351
# 55           23.7           22.228       1.472
# 75            8.7            8.655       0.045
# 150          16.1           15.316       0.784
# 104          20.7           20.562       0.138
# 135          11.6           12.098      -0.498
# 137          20.8           20.916      -0.116
# 164          11.9           12.326      -0.426
# 76            6.9            7.554      -0.654
